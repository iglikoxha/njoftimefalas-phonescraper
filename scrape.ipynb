# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
# Open headless browser only once
options = webdriver.FirefoxOptions()
options.add_argument("--headless")
driver = webdriver.Firefox(options=options)

for id in range(431630, 431640):
    url = f"https://www.njoftimefalas.com/23/oferta-vende-pune/id-{id}"
    driver.get(url) 

    html = driver.page_source

    soup = BeautifulSoup(html, "html.parser")
    print(soup.find(id=id))
# Out:
# None
# <a class="btn btn-default btn-block track" href="tel:0693467783" id="431631"><i aria-hidden="true" class="fa fa-phone"></i> 0693467783</a>
# <a class="btn btn-default btn-block track" href="tel:355693323906" id="431632"><i aria-hidden="true" class="fa fa-phone"></i> 355693323906</a>
# <a class="btn btn-default btn-block track" href="tel:0695136287" id="431633"><i aria-hidden="true" class="fa fa-phone"></i> 0695136287</a>
# <a class="btn btn-default btn-block track" href="tel:355692915204" id="431634"><i aria-hidden="true" class="fa fa-phone"></i> 355692915204</a>
# <a class="btn btn-default btn-block track" href="tel:00355693440400" id="431635"><i aria-hidden="true" class="fa fa-phone"></i> 00355693440400</a>
# <a class="btn btn-default btn-block track" href="tel:0696434099" id="431636"><i aria-hidden="true" class="fa fa-phone"></i> 0696434099</a>
# <a class="btn btn-default btn-block track" href="tel:0672226145" id="431637"><i aria-hidden="true" class="fa fa-phone"></i> 0672226145</a>
# <a class="btn btn-default btn-block track" href="tel:0672453573" id="431638"><i aria-hidden="true" class="fa fa-phone"></i> 0672453573</a>
# None
